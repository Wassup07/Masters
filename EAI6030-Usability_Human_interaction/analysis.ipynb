# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

'''Seaborn and Matplotlib Visualization'''
import matplotlib                  # 2D Plotting Library
import matplotlib.pyplot as plt
import seaborn as sns              # Python Data Visualization Library based on matplotlib
plt.style.use('fivethirtyeight')
# %matplotlib inline

'''Plotly Visualizations'''


'''Spatial Visualizations'''
import folium
import folium.plugins

'''NLP - WordCloud'''
import wordcloud
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
apple_improvement = ["Apple should notify the user of cookie settings on the site.",
                     "I think apple can improve the user interface a little"]
apple_preference = ["Load time for apple website was less , and it was easy to compare products at apple website",
                    "The visuals of Apple's website are much more clean and professional.",
                    "The transitions and animations of the webpages were seamless and pure eye candy.",
                    "I prefer apple website, because it’s user interface is extremely good compared to Samsung, and according to me , I easily found the product on apple website",
                    "I prefer apple website as it may look a little clumsy in the first glance but was quite easy and the product was also available . ",
                    "Simple and attractive UI"]
apple_comments = ["wanted iphone 12 pro, couldn't find it, had to settle with iphone 13, found unlocked version on first try; iphone 12 pro is available on the market but on the website",
                  "Additional price to buy an unlocked phone",
                  "customized it, bought an accessory with the it, an apple tag housing sold by apple, wasn't sure if item was added to cart",
                  "had some trouble finding the unlocked version after selecting a carrier",
                  "confused about mac naming in the tab, looking for macbook, liked the comparison between product tiers",
                  "got an accessory",
                  "bought additional accessories",
                  "checked the remove from cart option, couldn't find the undo button",
                  "Found the website hard to understand at first, the UI was clumsy and had trouble finding the color browser on the product page, used to search function, already new what exactly they want",
                  "read connect on your later, still couldn't figure out what it means"]

samsung_improvement = ["easy of finding products and ease of comparing them for samsung website",
                       "I would remove the permanent chat bot popup on the Samsung's web page",
                       "Better compartmentalize the Samsung products.",
                       "Popular and best selling products such as phones are better categorized than Samsung's laptops and accessories.",
                       "User should be able to easily manage Samsung's site's cookie setting through the notification.",
                       "It would be better if Samsun could have a different website for its mobile and home appliances.",
                       "samsung should work to improve on UI and product availability"]
samsung_comments = ["knew about samsung phone and wanted a specific one, website showed the price with trade in which was lower",
                    "No additional cost for unlocked",
                    "Looked at accessories, didn't buy any",
                    "more time was spent to find the product",
                    "went back before checkout page, item was not added to get bag, checked subscriptions and offer that come with the phone",
                    "no product description on the product page for a $1500 laptop ",
                    "found the accessory tab easily",
                    "noticed unlocked version was clearly mentioned, also noticed offers with phone, found the website a bit cluttered with a lot of things going on.",
                    "liked the recommendation system before the checkout page",
                    "confused about which category it should be in",
                    "had trouble getting to the checkout screen, the continue button was not working for the selected product, felt ui of apple was still better than samsung",
                    "wasn't able to find the no trade in option for sometime"]

# %%
from wordcloud import WordCloud, ImageColorGenerator

text = " ".join(str(each) for each in apple_preference)

# Create and generate a word cloud image:
wordcloud = WordCloud(max_words = 200, background_color = "white").generate(text)
plt.figure(figsize = (10,6))
plt.figure(figsize = (15,10))

# Display the generated image:
plt.imshow(wordcloud, interpolation = 'Bilinear')

plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud, ImageColorGenerator

text = " ".join(str(each) for each in apple_improvement)

# Create and generate a word cloud image:
wordcloud = WordCloud(max_words = 200, background_color = "white").generate(text)
plt.figure(figsize = (10,6))
plt.figure(figsize = (15,10))

# Display the generated image:
plt.imshow(wordcloud, interpolation = 'Bilinear')

plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud, ImageColorGenerator

text = " ".join(str(each) for each in apple_comments)

# Create and generate a word cloud image:
wordcloud = WordCloud(max_words = 200, background_color = "white").generate(text)
plt.figure(figsize = (10,6))
plt.figure(figsize = (15,10))

# Display the generated image:
plt.imshow(wordcloud, interpolation = 'Bilinear')

plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud, ImageColorGenerator

text = " ".join(str(each) for each in samsung_improvement)

# Create and generate a word cloud image:
wordcloud = WordCloud(max_words = 200, background_color = "white").generate(text)
plt.figure(figsize = (10,6))
plt.figure(figsize = (15,10))

# Display the generated image:
plt.imshow(wordcloud, interpolation = 'Bilinear')

plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud, ImageColorGenerator

text = " ".join(str(each) for each in samsung_comments)

# Create and generate a word cloud image:
wordcloud = WordCloud(max_words = 200, background_color = "white").generate(text)
plt.figure(figsize = (10,6))
plt.figure(figsize = (15,10))

# Display the generated image:
plt.imshow(wordcloud, interpolation = 'Bilinear')

plt.axis("off")
plt.show()

# %%
data = pd.read_excel("Time_and_click.xlsx")

# %%
data.head(10)
# Out:
#    S. No.        Name  Website  Time(s) Task1  Clicks Task1  Time(s) Task 2  \
# 0     1.0        Yash    Apple          183.0          26.0           112.0
# 1     1.0        Yash  Samsung          126.0          15.0           136.0
# 2     2.0       Tarun    Apple          182.0          15.0           163.0
# 3     2.0       Tarun  Samsung          177.0          25.0           173.0
# 4     3.0    Ashutosh    Apple          271.0          35.0           103.0
# 5     3.0    Ashutosh  Samsung          310.0          22.0           202.0
# 6     4.0  Aabhijatya    Apple          240.0          17.0           111.0
# 7     4.0  Aabhijatya  Samsung          104.0          11.0           158.0
# 8     5.0       Rohit    Apple          148.0          16.0            62.0
# 9     4.0  Aabhijatya  Samsung          227.0          53.0            76.0
#
#    Clicks Task 2  Time(s) Task 3  Clicks Task 3  Time(s) Total  Clicks Total  \
# ...

# %%
df_mean = data.groupby("Website").mean()
df_mean["Website"] = df_mean.index

# %%
df_mean
# Out:
#          S. No.  Time(s) Task1  Clicks Task1  Time(s) Task 2  Clicks Task 2  \
# Website
# Apple       3.0          204.8          21.8           110.2           10.0
# Samsung     2.8          188.8          25.2           149.0           10.8
#
#          Time(s) Task 3  Clicks Task 3  Time(s) Total  Clicks Total  \
# Website
# Apple             104.8            9.8          419.8          41.6
# Samsung            81.4            5.8          430.6          41.8
#
#              Ratio  Website
# Website
# Apple    10.440398    Apple
# Samsung  11.215903  Samsung

# %%
sns.barplot(x="Website",y="Ratio",data=df_mean)
plt.show()

# %%
list(df_mean.index)
# Out:
# ['Apple', 'Samsung']

# %%
df_mean["Time(s) Total"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_48616/1920659162.py in <module>
# ----> 1 df_mean["Time(s) Total"]
#
# NameError: name 'df_mean' is not defined

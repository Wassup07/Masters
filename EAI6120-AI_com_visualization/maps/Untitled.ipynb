# %%
import numpy as np
import pandas as pd
import missingno as msno
import matplotlib                  # 2D Plotting Library
import matplotlib.pyplot as plt
import seaborn as sns              # Python Data Visualization Library based on matplotlib
import plotly.express as px
plt.style.use('fivethirtyeight')
# %matplotlib inline
# ML Libraries

# %%
map_data = pd.read_csv("NST-EST2021-alldata.csv")

# %%
map_data.head()
# Out:
#    SUMLEV REGION DIVISION  STATE              NAME  ESTIMATESBASE2020  \
# 0      10      0        0      0     United States          331449281
# 1      20      1        0      0  Northeast Region           57609148
# 2      20      2        0      0    Midwest Region           68985454
# 3      20      3        0      0      South Region          126266107
# 4      20      4        0      0       West Region           78588572
#
#    POPESTIMATE2020  POPESTIMATE2021  NPOPCHG_2020  NPOPCHG_2021  ...  \
# 0        331501080        331893745         51799        392665  ...
# 1         57525633         57159838        -83515       -365795  ...
# 2         68935174         68841444        -50280        -93730  ...
# 3        126409007        127225329        142900        816322  ...
# 4         78631266         78667134         42694         35868  ...
#
#    NETMIG2020  NETMIG2021  RESIDUAL2020  RESIDUAL2021  RBIRTH2021  RDEATH2021  \
# 0       12247      244622             0             0   10.798957   10.352637
# 1      -79429     -333592         -1024         -1151    9.950554   10.492070
# 2      -47266      -85268          -718          5156   10.860566   11.058248
# 3      134454      770076           528         -3385   11.168835   10.777476
# 4        4488     -106594          1214          -620   10.767153    8.947910
#
#    RNATURALINC2021  RINTERNATIONALMIG2021  RDOMESTICMIG2021  RNETMIG2021
# 0         0.446319               0.737485          0.000000     0.737485
# 1        -0.541516               0.977386         -6.794897    -5.817511
# 2        -0.197682               0.549222         -1.786994    -1.237772
# 3         0.391359               0.886268          5.186064     6.072332
# 4         1.819243               0.487570         -1.842880    -1.355309
#
# [5 rows x 30 columns]

# %%
map_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 30 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   SUMLEV                 57 non-null     int64
#  1   REGION                 57 non-null     object
#  2   DIVISION               57 non-null     object
#  3   STATE                  57 non-null     int64
#  4   NAME                   57 non-null     object
#  5   ESTIMATESBASE2020      57 non-null     int64
#  6   POPESTIMATE2020        57 non-null     int64
#  7   POPESTIMATE2021        57 non-null     int64
#  8   NPOPCHG_2020           57 non-null     int64
#  9   NPOPCHG_2021           57 non-null     int64
#  10  BIRTHS2020             57 non-null     int64
#  11  BIRTHS2021             57 non-null     int64
#  12  DEATHS2020             57 non-null     int64
#  13  DEATHS2021             57 non-null     int64
#  14  NATURALINC2020         57 non-null     int64
#  15  NATURALINC2021         57 non-null     int64
#  16  INTERNATIONALMIG2020   57 non-null     int64
#  17  INTERNATIONALMIG2021   57 non-null     int64
#  18  DOMESTICMIG2020        57 non-null     int64
#  19  DOMESTICMIG2021        57 non-null     int64
#  20  NETMIG2020             57 non-null     int64
#  21  NETMIG2021             57 non-null     int64
#  22  RESIDUAL2020           57 non-null     int64
#  23  RESIDUAL2021           57 non-null     int64
#  24  RBIRTH2021             57 non-null     float64
#  25  RDEATH2021             57 non-null     float64
#  26  RNATURALINC2021        57 non-null     float64
#  27  RINTERNATIONALMIG2021  57 non-null     float64
#  28  RDOMESTICMIG2021       57 non-null     float64
#  29  RNETMIG2021            57 non-null     float64
# dtypes: float64(6), int64(21), object(3)
# memory usage: 13.5+ KB

# %%
import numpy as np
import pandas as pd
import missingno as msno
import matplotlib                  # 2D Plotting Library
import matplotlib.pyplot as plt
import seaborn as sns              # Python Data Visualization Library based on matplotlib
import plotly.express as px
plt.style.use('fivethirtyeight')
# %matplotlib inline
# ML Libraries

# %%
nyc_data = pd.read_csv("nyc_311_cleaned_final.csv")

# %%
nyc_data.head()
# Out:
#    Unnamed: 0  unique_key         created_date          closed_date agency  \
# 0           0    50727696  2021-05-31 10:35:53  2021-05-31 11:20:12   NYPD
# 1           1    50727697  2021-05-31 21:43:29  2021-05-31 22:07:30   NYPD
# 2           2    50727698  2021-05-31 21:06:29  2021-05-31 23:41:58   NYPD
# 3           3    50727699  2021-06-01 00:38:44  2021-06-01 01:06:24   NYPD
# 4           4    50727701  2021-05-31 23:56:13  2021-06-01 01:36:23   NYPD
#
#                        agency_name           complaint_type        descriptor  \
# 0  New York City Police Department  Noise - Street/Sidewalk  Loud Music/Party
# 1  New York City Police Department  Noise - Street/Sidewalk  Loud Music/Party
# 2  New York City Police Department  Noise - Street/Sidewalk  Loud Music/Party
# 3  New York City Police Department  Noise - Street/Sidewalk  Loud Music/Party
# 4  New York City Police Department  Noise - Street/Sidewalk  Loud Music/Party
#
#      location_type  incident_zip  ...    borough x_coordinate__state_plane  \
# 0  Street/Sidewalk       11226.0  ...   BROOKLYN                  995653.0
# 1  Street/Sidewalk       11216.0  ...   BROOKLYN                  998668.0
# 2  Street/Sidewalk       10027.0  ...  MANHATTAN                  997097.0
# 3  Street/Sidewalk       10455.0  ...      BRONX                 1009028.0
# 4  Street/Sidewalk       10468.0  ...      BRONX                 1011674.0
#
#   y_coordinate__state_plane open_data_channel_type park_facility_name  \
# 0                  178165.0                 ONLINE        Unspecified
# 1                  189402.0                 MOBILE        Unspecified
# 2                  233603.0                 MOBILE        Unspecified
# 3                  237023.0                 MOBILE        Unspecified
# 4                  252336.0                 ONLINE        Unspecified
#
#   park_borough   latitude  longitude                                 location  \
# 0     BROOKLYN  40.655691 -73.958903  (40.65569111712253, -73.95890294017106)
# 1     BROOKLYN  40.686530 -73.948013  (40.68652976515426, -73.94801267589376)
# 2    MANHATTAN  40.807853 -73.953593   (40.80785278615901, -73.9535928323277)
# 3        BRONX  40.817214 -73.910482    (40.81721432378433, -73.910481925689)
# 4        BRONX  40.859236 -73.900860  (40.85923621735196, -73.90085983937489)
#
#    resolution_mins
# 0        44.316667
# 1        24.016667
# 2       155.483333
# 3        27.666667
# 4       100.166667
#
# [5 rows x 27 columns]

# %%
nyc_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1917615 entries, 0 to 1917614
# Data columns (total 27 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   Unnamed: 0                      int64
#  1   unique_key                      int64
#  2   created_date                    object
#  3   closed_date                     object
#  4   agency                          object
#  5   agency_name                     object
#  6   complaint_type                  object
#  7   descriptor                      object
#  8   location_type                   object
#  9   incident_zip                    float64
#  10  incident_address                object
#  11  street_name                     object
#  12  city                            object
#  13  status                          object
#  14  resolution_description          object
#  15  resolution_action_updated_date  object
#  16  community_board                 object
#  17  borough                         object
#  18  x_coordinate__state_plane       float64
#  19  y_coordinate__state_plane       float64
#  20  open_data_channel_type          object
#  21  park_facility_name              object
#  22  park_borough                    object
#  23  latitude                        float64
#  24  longitude                       float64
#  25  location                        object
#  26  resolution_mins                 float64
# dtypes: float64(6), int64(2), object(19)
# memory usage: 395.0+ MB

# %%
nyc_data.
